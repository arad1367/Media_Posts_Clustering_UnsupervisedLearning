# %%
# I supposed that, you have your data in your google drive and just mount drive, Unzip the data
from google.colab import drive
drive.mount('/content/drive')

# %%
# Unzipping the file
# !unzip /content/drive/MyDrive/LLM_ART_Projects/ClusterData.zip -d /content/drive/MyDrive/LLM_ART_Projects/
# Out:
# Archive:  /content/drive/MyDrive/LLM_ART_Projects/ClusterData.zip
#    creating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00001.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00002.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00003.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00004.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00005.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00006.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00007.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00008.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00009.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00010.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00011.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00012.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00013.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00014.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00015.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00016.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00017.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00018.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00019.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00020.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00021.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00022.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00023.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00024.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00025.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00026.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00027.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00028.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00029.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00030.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00031.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00032.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00033.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00034.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00035.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00036.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00037.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00038.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00039.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00040.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00041.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00042.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00043.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00044.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00045.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00046.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00047.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00048.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00049.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00050.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00051.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00052.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00053.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00054.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00055.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00056.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00057.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00058.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00059.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00060.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00061.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00062.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00063.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00064.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00065.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00066.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00067.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00068.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00069.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00070.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00071.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00072.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00073.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00074.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00075.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00076.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00077.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00078.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00079.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00080.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00081.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00082.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00083.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00084.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00085.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00086.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00087.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00088.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00089.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00090.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00091.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00092.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00093.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00094.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00095.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00096.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00097.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00098.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00099.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00100.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00101.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00102.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00103.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00104.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00105.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00106.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00107.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00108.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00109.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00110.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00111.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00112.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00113.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00114.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00115.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00116.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00117.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00118.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00119.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00120.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00121.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00122.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00123.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00124.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00125.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00126.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00127.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00128.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00129.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00130.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00131.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00132.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00133.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00134.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00135.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00136.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00137.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00138.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00139.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00140.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00141.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00142.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00143.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00144.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00145.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00146.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00147.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00148.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00149.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00150.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00151.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00152.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00153.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00154.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00155.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00156.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00157.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00158.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00159.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00160.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00161.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00162.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00163.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00164.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00165.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00166.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00167.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00168.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00169.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00170.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00171.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00172.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00173.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00174.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00175.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00176.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00177.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00178.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00179.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00180.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00181.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00182.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00183.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00184.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00185.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00186.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00187.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00188.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00189.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00190.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00191.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00192.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00193.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00194.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00195.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00196.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00197.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00198.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00199.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00200.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00201.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00202.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00203.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00204.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00205.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00206.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00207.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00208.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00209.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00210.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00211.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00212.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00213.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00214.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00215.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00216.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00217.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00218.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00219.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00220.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00221.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00222.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00223.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00224.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00225.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00226.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00227.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00228.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00229.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00230.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00231.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00232.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00233.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00234.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00235.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00236.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00237.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00238.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00239.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00240.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00241.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00242.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00243.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00244.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00245.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00246.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00247.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00248.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00249.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00250.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00251.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00252.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00253.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00254.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00255.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00256.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00257.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00258.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00259.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00260.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00261.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00262.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00263.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00264.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00265.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00266.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00267.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00268.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00269.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00270.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00271.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00272.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00273.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00274.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00275.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00276.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00277.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00278.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00279.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00280.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00281.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00282.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00283.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00284.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00285.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00286.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00287.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00288.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00289.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00290.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00291.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00292.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00293.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00294.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00295.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00296.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00297.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00298.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00299.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00300.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00301.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00302.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00303.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00304.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00305.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00306.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00307.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00308.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00309.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00310.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00311.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00312.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00313.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00314.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00315.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00316.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00317.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00318.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00319.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00320.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00321.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00322.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00323.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00324.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00325.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00326.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00327.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00328.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00329.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00330.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00331.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00332.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00333.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00334.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00335.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00336.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00337.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00338.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00339.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00340.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00341.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00342.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00343.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00344.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00345.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00346.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00347.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00348.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00349.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00350.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00351.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00352.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00353.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00354.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00355.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00356.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00357.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00358.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00359.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00360.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00361.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00362.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00363.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00364.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00365.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00366.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00367.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00368.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00369.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00370.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00371.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00372.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00373.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00374.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00375.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00376.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00377.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00378.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00379.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00380.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00381.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00382.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00383.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00384.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00385.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00386.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00387.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00388.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00389.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00390.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00391.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00392.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00393.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00394.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00395.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00396.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00397.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00398.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00399.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00400.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00401.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00402.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00403.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00404.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00405.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00406.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00407.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00408.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00409.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00410.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00411.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00412.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00413.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00414.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00415.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00416.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00417.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00418.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00419.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00420.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00421.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00422.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00423.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00424.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00425.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00426.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00427.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00428.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00429.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00430.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00431.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00432.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00433.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00434.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00435.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00436.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00437.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00438.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00439.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00440.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00441.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00442.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00443.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00444.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00445.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00446.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00447.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00448.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00449.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00450.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00451.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00452.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00453.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00454.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00455.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00456.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00457.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00458.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00459.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00460.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00461.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00462.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00463.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00464.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00465.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00466.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00467.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00468.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00469.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00470.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00471.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00472.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00473.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00474.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00475.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00476.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00477.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00478.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00479.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00480.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00481.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00482.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00483.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00484.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00485.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00486.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00487.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00488.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00489.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00490.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00491.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00492.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00493.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00494.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00495.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00496.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00497.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00498.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00499.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00500.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00501.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00502.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00503.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00504.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00505.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00506.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00507.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00508.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00509.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00510.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00511.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00512.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00513.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00514.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00515.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00516.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00517.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00518.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00519.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00520.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00521.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00522.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00523.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00524.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00525.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00526.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00527.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00528.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00529.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00530.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00531.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00532.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00533.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00534.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00535.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00536.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00537.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00538.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00539.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00540.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00541.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00542.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00543.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00544.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00545.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00546.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00547.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00548.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00549.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00550.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00551.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00552.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00553.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00554.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00555.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00556.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00557.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00558.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00559.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00560.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00561.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00562.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00563.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00564.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00565.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00566.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00567.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00568.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00569.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00570.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00571.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00572.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00573.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00574.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00575.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00576.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00577.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00578.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00579.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00580.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00581.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00582.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/cats_00583.jpg
# ...
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00809.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00810.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00811.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00812.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00813.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00814.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00815.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00816.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00817.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00818.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00819.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00820.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00821.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00822.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00823.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00824.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00825.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00826.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00827.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00828.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00829.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00830.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00831.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00832.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00833.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00834.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00835.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00836.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00837.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00838.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00839.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00840.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00841.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00842.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00843.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00844.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00845.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00846.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00847.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00848.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00849.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00850.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00851.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00852.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00853.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00854.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00855.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00856.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00857.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00858.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00859.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00860.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00861.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00862.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00863.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00864.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00865.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00866.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00867.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00868.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00869.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00870.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00871.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00872.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00873.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00874.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00875.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00876.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00877.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00878.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00879.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00880.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00881.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00882.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00883.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00884.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00885.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00886.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00887.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00888.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00889.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00890.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00891.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00892.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00893.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00894.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00895.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00896.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00897.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00898.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00899.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00900.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00901.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00902.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00903.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00904.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00905.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00906.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00907.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00908.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00909.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00910.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00911.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00912.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00913.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00914.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00915.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00916.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00917.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00918.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00919.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00920.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00921.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00922.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00923.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00924.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00925.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00926.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00927.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00928.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00929.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00930.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00931.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00932.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00933.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00934.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00935.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00936.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00937.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00938.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00939.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00940.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00941.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00942.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00943.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00944.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00945.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00946.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00947.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00948.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00949.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00950.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00951.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00952.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00953.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00954.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00955.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00956.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00957.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00958.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00959.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00960.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00961.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00962.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00963.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00964.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00965.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00966.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00967.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00968.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00969.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00970.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00971.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00972.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00973.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00974.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00975.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00976.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00977.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00978.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00979.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00980.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00981.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00982.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00983.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00984.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00985.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00986.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00987.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00988.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00989.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00990.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00991.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00992.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00993.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00994.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00995.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00996.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00997.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00998.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_00999.jpg
#   inflating: /content/drive/MyDrive/LLM_ART_Projects/ClusterData/panda_01000.jpg

# %%
# Path to whole data
data_path = "/content/drive/MyDrive/LLM_ART_Projects/ClusterData/"
media_data_path = "/content/drive/MyDrive/LLM_ART_Projects/Mix_Media_Posts/"   # Don't forget last /

# %%
# !pip install --upgrade tensorflow keras
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Collecting keras
#   Downloading keras-3.5.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.8.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Downloading keras-3.5.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 5.1 MB/s eta 0:00:00
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
# Successfully installed keras-3.5.0

# %%
#Importing the required libraries
import os            #For Searching and accessing files in the directories
import cv2           #To Read and write images
import numpy as np   #To perform matrix operations on image arrays
from tensorflow.keras.models import load_model, Model      #To design and deploy deep learning models
from sklearn.cluster import KMeans                         #Clustering algorithm
import matplotlib.pyplot as plt
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input  #VGG16 model for transfer learning
from tensorflow.keras.preprocessing import image                         #Tensor operaitons on images
from tensorflow.keras.utils import plot_model                            #To plot the model
import matplotlib.image as mpimg              #Plotting images
import matplotlib.cm as cm
from sklearn.metrics import silhouette_samples, silhouette_score         #Cluster performance evaluation
from tabulate import tabulate      #For displaying results

# %matplotlib inline

# %%
#Model function
def get_model(layer='fc2'):

    base_model = VGG16(weights='imagenet', include_top=True) #VGG model import trained with imagenet dataset
    model = Model(inputs=base_model.input,                   #Creating the model with layer 'fc2' as an output layer
                outputs=base_model.get_layer(layer).output)
    return model

# %%
#Function to access the image files form the dataset
def get_files(path_to_files, size):
    fn_imgs = []
    files = [file for file in os.listdir(path_to_files)]       #Storing all image files names
    for file in files:
        img = cv2.resize(cv2.imread(path_to_files+file), size) #Reading and resizing each image
        fn_imgs.append([file, img])             #Accumulating each image to a variable
    return dict(fn_imgs)                        #Returning the dictionary of all the image and their names

# %%
#Obtaining features from each image
def feature_vector(img_arr, model):          #Function takes the image array and the VGG model as input
    if img_arr.shape[2] == 1:
      img_arr = img_arr.repeat(3, axis=2)    #Repeat grayscale pixel values to three color channels

    arr4d = np.expand_dims(img_arr, axis=0)  #Expanding image dimension (1, 224, 224, 3) to make it compatable with keras model
    arr4d_pp = preprocess_input(arr4d)
    return model.predict(arr4d_pp)[0,:]      #Returning image features through VGG16 net

# %%
#Extracting features from all the images
def feature_vectors(imgs_dict, model):
    f_vect = {}
    for fn, img in imgs_dict.items():         #For loop over each image in the imgs_dict
      f_vect[fn] = feature_vector(img, model) #Calling feature vector function to extract the features
    return f_vect                             #Returning features

# %%
#Creating the model
model = get_model()

#Model summary
model.summary()

#Plotting the model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc1 (Dense)                          │ (None, 4096)                │     102,764,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc2 (Dense)                          │ (None, 4096)                │      16,781,312 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 134,260,544 (512.16 MB)
#  Trainable params: 134,260,544 (512.16 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# img_path = data_path
img_path = media_data_path

imgs_dict = get_files(path_to_files = img_path ,size = (224, 224))   #Getting image files and resizing

# Feed images through the model and extract feature vectors.
img_feature_vector = feature_vectors(imgs_dict, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step

# %%
''' In this code cell we determine the optimal number of clusters to be detected
    in our image dataset. The method used for it is called the elbow method. In
    this method we perform the clustering algorithm for a range of cluster values
    and then calculate the variance in each cluster. The variance is then plotted
    agains the cluster numbers. The point where the curve bends and makes an
    elbow shape is then choosen to be optimal number of clusters since after
    this point the variance decreases very slowly.'''

images = list(img_feature_vector.values())    #Image feature vectors
fns = list(img_feature_vector.keys())         #Image file names
sum_of_squared_distances = []                 #Initializing the variance
K = range(1, 30)                              #Range of clusters to be tried
for k in K:                                   #For loop over the cluster range
    km = KMeans(n_clusters=k)                 #KNN object with cluster number
    km = km.fit(images)                       #Running cluster algorithm
    sum_of_squared_distances.append(km.inertia_)   #Calculating the variance

#Plotting the variance
fig, ax = plt.subplots(figsize=(12, 6))
plt.plot(K, sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k based on variance')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
#Running clustering algorithm with optimal number of clusters
n_clusters = 4    #Optimal number of clusters
kmeans = KMeans(n_clusters=n_clusters, init='k-means++')  #Initializing clustering object
kmeans.fit(images)                     #Fitting the clustering object to the dataset
y_kmeans = kmeans.predict(images)      #Predicting clusters for each image in the dataset
file_names = list(imgs_dict.keys())
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
cluster_path = img_path    #Path to store the clusters
path_to_files = img_path   #Path to image dataset

#Creating each cluster directory
for c in range(0,n_clusters):
    if not os.path.exists(cluster_path+'cluster_'+str(c)):
        os.mkdir(cluster_path+'cluster_'+str(c))

#Storing each image to different clusters it belongs to
for fn, cluster in zip(file_names, y_kmeans):
    image = cv2.imread(path_to_files+fn)
    cv2.imwrite(cluster_path+'cluster_'+str(cluster)+'/'+fn, image)

# %%
'''In this cell code we evaluate the performance of our clustering algorithm.
   since clustering is an unsupervised learning technique, thus there is no
   direct method to evaluate its performance since we dont have the ground truth
   available. The performance metric used here is called the silhouette analysis.
   It is basically a measure of how similar the members in the same cluster are
   and how different they are from the neighbour clusters.'''

fig, ax = plt.subplots(figsize=(12, 6))        #Empty figure

# The silhouette coefficient can range from -1, 1 but in this example all
# lie within [-0.1, 0.5]
ax.set_xlim([-0.1, 0.5])                               #X-axis limit
ax.set_ylim([0, len(images) + (n_clusters + 1) * 10])  #Y-axis limit

# Compute the silhouette scores for each image
sample_silhouette_values = silhouette_samples(images, y_kmeans)
# Compute the average silhouette score
silhouette_avg = silhouette_score(images, y_kmeans)

y_lower = 10
#For loop over each image in the respective cluster
for i in range(n_clusters):
  # Aggregate the silhouette scores for samples belonging to
  # cluster i, and sort them
  ith_cluster_silhouette_values = \
      sample_silhouette_values[y_kmeans == i]

  ith_cluster_silhouette_values.sort() #Sorting each cluster score

  #Setting limit for each cluster in y-axis
  size_cluster_i = ith_cluster_silhouette_values.shape[0]
  y_upper = y_lower + size_cluster_i

  #Setting color for each cluster's silhouette coefficients
  color = cm.nipy_spectral(float(i) / n_clusters)
  ax.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

  # Label the silhouette plots with their cluster numbers at the middle
  ax.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

  # Compute the new y_lower for next plot
  y_lower = y_upper + 10  # 10 for the 0 samples

#Titles for the plot
ax.set_title("The silhouette plot for the various clusters.")
ax.set_xlabel("The silhouette coefficient values")
ax.set_ylabel("Cluster label")

# The vertical line for average silhouette score of all the values
ax.axvline(x=silhouette_avg, color="red", linestyle="--")

ax.set_yticks([])  # Clear the yaxis labels / ticks
ax.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold');

#Printing the average silhouette score for the clusters
print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)
# Out:
# For n_clusters = 4 The average silhouette_score is : 0.21670562

# %%
#Plotting images in each cluster
fig = plt.figure(figsize=(14, 14))    #Empty figure

cluster_no = 'cluster_0/'             #Cluster number to be plotted

cluster_path = img_path + cluster_no  #Path to specified cluster images
images = [file for file in os.listdir(cluster_path)]  #Image file names in the specified cluster path

for cnt, data in enumerate(images[1:30]): #For loop over the first 30 images in the cluster
    y = fig.add_subplot(6, 5, cnt+1)      #Creating subplots
    img = mpimg.imread(cluster_path+data) #Reading the image
    y.imshow(img)                         #Plotting the image
    plt.title(cluster_no)                 #Cluster number as a title over the image
    y.axes.get_xaxis().set_visible(False)
    y.axes.get_yaxis().set_visible(False)

cluster0_imgs_total = len(images)

# %%
#Plotting images in each cluster
fig = plt.figure(figsize=(14, 14))    #Empty figure

cluster_no = 'cluster_1/'             #Cluster number to be plotted

cluster_path = img_path + cluster_no  #Path to specified cluster images
images = [file for file in os.listdir(cluster_path)]  #Image file names in the specified cluster path

for cnt, data in enumerate(images[1:30]): #For loop over the first 30 images in the cluster
    y = fig.add_subplot(6, 5, cnt+1)      #Creating subplots
    img = mpimg.imread(cluster_path+data) #Reading the image
    y.imshow(img)                         #Plotting the image
    plt.title(cluster_no)                 #Cluster number as a title over the image
    y.axes.get_xaxis().set_visible(False)
    y.axes.get_yaxis().set_visible(False)

cluster1_imgs_total = len(images)

# %%
#Plotting images in each cluster
fig = plt.figure(figsize=(14, 14))    #Empty figure

cluster_no = 'cluster_2/'             #Cluster number to be plotted

cluster_path = img_path + cluster_no  #Path to specified cluster images
images = [file for file in os.listdir(cluster_path)]  #Image file names in the specified cluster path

for cnt, data in enumerate(images[1:30]): #For loop over the first 30 images in the cluster
    y = fig.add_subplot(6, 5, cnt+1)      #Creating subplots
    img = mpimg.imread(cluster_path+data) #Reading the image
    y.imshow(img)                         #Plotting the image
    plt.title(cluster_no)                 #Cluster number as a title over the image
    y.axes.get_xaxis().set_visible(False)
    y.axes.get_yaxis().set_visible(False)

cluster2_imgs_total = len(images)

# %%
#Plotting images in each cluster
fig = plt.figure(figsize=(14, 14))    #Empty figure

cluster_no = 'cluster_3/'             #Cluster number to be plotted

cluster_path = img_path + cluster_no  #Path to specified cluster images
images = [file for file in os.listdir(cluster_path)]  #Image file names in the specified cluster path

for cnt, data in enumerate(images[1:30]): #For loop over the first 30 images in the cluster
    y = fig.add_subplot(6, 5, cnt+1)      #Creating subplots
    img = mpimg.imread(cluster_path+data) #Reading the image
    y.imshow(img)                         #Plotting the image
    plt.title(cluster_no)                 #Cluster number as a title over the image
    y.axes.get_xaxis().set_visible(False)
    y.axes.get_yaxis().set_visible(False)

cluster3_imgs_total = len(images)

# %%
img_total = len(img_feature_vector)    #Total number of images in the dataset

percent_dup_removed = (1-(n_clusters/img_total))*100     #Percent duplication removed


# Creating dataset
Clusters_t = ['Cluster_0', 'Cluster_1', 'Cluster_2', 'Cluster_2']

p_d_c0 = (cluster0_imgs_total/img_total)*percent_dup_removed       #Percent duplication in cluster0
p_d_c1 = (cluster1_imgs_total/img_total)*percent_dup_removed       #Percent duplication in cluster1
p_d_c2 = (cluster2_imgs_total/img_total)*percent_dup_removed       #Percent duplication in cluster2
p_d_c3 = (cluster3_imgs_total/img_total)*percent_dup_removed

table = [['Category', 'Images', 'Duplication (%)'], ['Cluster_0', str(cluster0_imgs_total), p_d_c0], ['Cluster_1', str(cluster1_imgs_total), p_d_c1], ['Cluster_2', str(cluster2_imgs_total), p_d_c2],['Cluster_2', str(cluster3_imgs_total), p_d_c3],['Total', str(img_total), percent_dup_removed]]

print('The details of overall duplication percentage and per are presented in the below table')
print(tabulate(table, headers='firstrow', tablefmt='grid'))
# Out:
# The details of overall duplication percentage and per are presented in the below table
# +------------+----------+-------------------+
# | Category   |   Images |   Duplication (%) |
# +============+==========+===================+
# | Cluster_0  |       29 |           27.5757 |
# +------------+----------+-------------------+
# | Cluster_1  |       23 |           21.8704 |
# +------------+----------+-------------------+
# | Cluster_2  |       27 |           25.674  |
# +------------+----------+-------------------+
# | Cluster_2  |       22 |           20.9195 |
# +------------+----------+-------------------+
# | Total      |      101 |           96.0396 |
# +------------+----------+-------------------+

# %%
data = [p_d_c0, p_d_c1, p_d_c2, p_d_c3]

# Creating explode data
explode = (0.1, 0.0, 0.2, 0.3)

# Creating color parameters
colors = ("orange", "cyan", "brown", "black")

# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "green" }

# Creating autocpt arguments
def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:.1f}%\n({:d} )".format(pct, absolute)

# Creating plot
fig, ax = plt.subplots(figsize =(10, 7))
wedges, texts, autotexts = ax.pie(data,
                                  autopct = lambda pct: func(pct, data),
                                  explode = explode,
                                  labels = Clusters_t,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="magenta"))

# Adding legend
ax.legend(wedges, Clusters_t,
          title ="Clusters",
          loc ="center left",
          bbox_to_anchor =(1, 0, 0.5, 1))

plt.setp(autotexts, size = 8, weight ="bold")
ax.set_title("Percent Duplication removed per Cluster")

# show plot
plt.show()

# %%
# create a dataset
height = [cluster0_imgs_total, cluster1_imgs_total, cluster2_imgs_total, cluster3_imgs_total]
bars = ('Cluster_0','Cluster_1','Cluster_2', 'Cluster_3')
x_pos = np.arange(len(bars))

# Create bars with different colors
fig = plt.figure(figsize=(15, 5))
plt.bar(x_pos, height, color=['red', 'green', 'cyan'],edgecolor='blue')

# Create names on the x-axis
plt.xticks(x_pos, bars)
plt.ylabel('Images')
plt.xlabel('Clusters')
plt.grid( linestyle='--', linewidth=2, axis='y', alpha=0.7)

plt.title('Duplicate Images per Cluster')

# Show graph
plt.show()
